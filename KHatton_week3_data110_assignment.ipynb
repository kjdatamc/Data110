# %% [markdown]
# <a href="https://colab.research.google.com/github/kjdatamc/Data110/blob/main/KHatton_week3_data110_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 3: Matplotlib Line and Scatter Plots Assignment

# %% [markdown]
# ### 1. Setup and Styles
#
# - Import the necessary libraries (Matplotlib and NumPy)
# - Use the following code to print out all available styles:
#   ```python
#   import matplotlib.pyplot as plt
#   print(plt.style.available)
#   ```
# - Set the default style to 'seaborn-whitegrid'
# - Choose one additional style from the available list to use later in the assignment

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-whitegrid')
#save for later:'dark_background'

# %%
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# ### 2. Basic Line Plot
#
# - Create a plot of the quadratic function ion $f(x) = x^2 - 2x + 1$ over the range [ − 2 , 4 ]
# - Use `plt.plot()` to create the plot

# %%
x=np.linspace(-2,4)
y=pow(x,2)-(2*x)+1
plt.plot(x,y);

# %% [markdown]
# ### 3. Multiple Lines
#
# - Create a plot with the following three functions on the same graph:
#  - $f(x) = x^3$
#  - $g(x) = e^x$
#  - $h(x) = \log ⁡(x)$ (for $x > 0$)
# - Use different colors for each line
# - Add a legend to distinguish between the functions

# %%
x=np.linspace(-2,4,500)

f_3=pow(x,3)
plt.plot(x,f_3,color='#00f5f5',label='$f(x)=x^3$')

g_3=np.e**x
plt.plot(x,g_3,color='#00a5a5',label='$g(x)=e^x$')

x_clipped=np.clip(x, 0.001, None)
h_3=np.log(x_clipped)
plt.plot(x_clipped,h_3,color='#004545',label='$h(x)=log(x)$')

plt.legend()

plt.show()

# %% [markdown]
# ### 4. Styling Lines
#
# - Create a plot with the following functions, each with a different color and line style:
#  - $f(x) = x^2$
#  - $g(x) = x^3$
#  - $h(x) = x^4$
#  - $i(x) = x^5$
# - Demonstrate at least 4 different color specification methods

# %%
x=np.linspace(-3,3,500)

#hex code
f_4=pow(x,2)
plt.plot(x,f_4,'-',color='#00f5f5',label='$f(x)=x^2$')

#named xkcd color
g_4=pow(x,3)
plt.plot(x,g_4,':',color='xkcd:teal',label='$g(x)=x^3$')

#RGB tuple
h_4=pow(x,4)
plt.plot(x,h_4,'--',color=(0,.3,.3),label='$h(x)=x^4$')

#single letter color string
i_4=pow(x,5)
plt.plot(x,i_4,'-.k',label='$i(x)=x^5$')

plt.legend()

plt.show()

# %% [markdown]
# ### 5. Axes Limits and Scaling
#
# - Plot the function $f(x) = \frac{1}{x^2 + 1}$ over the range [ − 10 , 10 ]
# - Set appropriate custom x and y limits to showcase the function's behavior
# - Create another plot of the same function with reversed x and y axes
# - Demonstrate the use of `plt.axis('tight')` and `plt.axis('equal')`

# %%
x=np.linspace(-10,10,500)

f_5=1/((x**2)+1)
plt.plot(x,f_5,color='tab:cyan',label='$f(x)= 1/(x^2 + 1)$')

plt.xlim(-10,10)
plt.ylim(-.25,1.25)

plt.legend()

plt.show()

# %%
#using plt.axis('tight')
x=np.linspace(-10,10,500)

f_5=1/((x**2)+1)
plt.plot(x,f_5,color='tab:blue',label='$f(x)= 1/(x^2 + 1)$')

plt.axis('tight')

plt.title(" $f(x)= 1/(x^2 + 1)$ [plt.axis('tight')] ")

plt.legend()

plt.show()

# %%
#using plt.axis('equal')
y=np.linspace(-10,10,500)

f_5=1/((x**2)+1)
plt.plot(x,f_5,color='tab:green',label='$f(x)= 1/(x^2 + 1)$')

plt.axis('equal')

plt.title(" $f(x)= 1/(x^2 + 1)$ [plt.axis('equal')] ")

plt.legend()

plt.show()

# %%
#swap x and y axes
x=np.linspace(-10,10,500)

f_5=1/((x**2)+1)
plt.plot(f_5,x,color='tab:orange',label='$f(x)= 1/(x^2 + 1)$')

plt.xlim(-0.25,1.25)
plt.ylim(-10,10)

plt.xlabel('$f(x)$')
plt.ylabel('$x$')

plt.title(" $f(x)= 1/(x^2 + 1)$ [Swap x-axis and y-axis] ")

plt.legend()

plt.show()

# %% [markdown]
# ### 6. Labels and Legends
#
# - Create a plot of $f(x) = \sqrt{x}$ and $g(x) = x^{\frac{1}{3}}$ for $x \geq 0$
# - Add a proper title, x-label, y-label, and legend

# %%
x=np.linspace(0,5,500)

f_6=np.sqrt(x)
plt.plot(x,f_6,color='#00f5f5',label='$f(x) = \sqrt{x}$')

g_6=x**(1/3)
plt.plot(x,g_6,color='#006767',label='$g(x) = x^{1/3}$')

plt.ylim(-.5,5)
plt.xlim(-.5,5)

plt.xlabel('x')
plt.ylabel('y')
plt.title(" Comparison of f(x) and g(x) ")

plt.legend();

# %% [markdown]
# ### 7. Basic Scatter Plot
#
# - Generate 50 random points using `np.random.rand()` for both x and y
# - Create a scatter plot of these points using `plt.plot()` with the 'o' marker
# - Create the same scatter plot using `plt.scatter()`

# %%
x=np.random.rand(50)
y=np.random.rand(50)

plt.plot(x,y,'og')

plt.title(" Sample (plt.plot) ")

plt.show()

# %%
plt.scatter(x,y,marker='o',color='g')

plt.title(" Sample (plt.scatter) ")

plt.show()

# %% [markdown]
# ### 8. Customizing Scatter Plots
#
# - Generate data for the function $f(x) = x sin(x)$ over the range [ 0 , 4π ]
# - Create a scatter plot of this data with a line connecting the points
# - Customize the plot by changing the marker size, line width, marker face color, marker edge color, and marker edge width

# %%
x_8=np.linspace(0,4*np.pi)

f_8=x_8*np.sin(x_8)
plt.plot(x_8,f_8,'-o', color='k',
         markersize=10, linewidth=2,
         markerfacecolor='#ee99ee',
         markeredgecolor='k',
         markeredgewidth=2)

plt.title(" $f(x) = x sin(x)$ ")

plt.show()

# %% [markdown]
# ### 9. Combined Plot
# - Plot the function $f(x) = x \cos(x)$ over the range $[-2\pi, 2\pi]$
# - Add scatter points for x values at every $\frac{\pi}{4}$ interval
# - Use different colors and styles for the line and scatter components

# %%
x_9=np.linspace(-2*np.pi,2*np.pi,17)

f_9=x_9*np.cos(x_9)
plt.plot(x_9,f_9,':sb',
         markersize=10, linewidth=2,
         markerfacecolor='#99eeee',
         markeredgecolor='c',
         markeredgewidth=2)

plt.title(" $f(x) = x cos(x)$ ")

plt.show()

# %% [markdown]
# ### 10. Custom Plot with Alternative Style
# - Choose two or more functions from the following list:
#   - $f(x) = \tan(x)$
#   - $g(x) = x e^{-x^2}$
#   - $h(x) = \frac{\sin(x)}{x}$  (with appropriate handling for $x=0$)
#   - $i(x) = \arctan(x)$
#   - $j(x) = \frac{1}{1 + e^{-x}}$  (logistic function)
# - Create a custom plot that combines at least 4 concepts learned (e.g., multiple functions, scatter points, custom colors, line styles, limits, labels, and legend)
# - Use the alternative style you chose in Task 1 for this plot
# - Add comments explaining your choices, the significance of the functions you chose, and how the alternative style affects the plot's appearance

# %% [markdown]
# #### Notes on my selected functions:
# I chose to compare $tan(x)$ and $arctan(x)$ because they're inverse functions, and I thought it would be interesting to look at how these inverse functions graph differently. I didn't limit the number of points plotted because it negatively impacted the appearance of the $tan(x)$ function when I tested using 17 and 33 points. The function has vertical asymptotes that didn't show up well.
#
# I used the `dark_background` plot style because the dark plot would be very distinct from the light `seaborn` style of the rest of the exercise.

# %%
plt.style.use('dark_background')

# %%
x_10=np.linspace(-1*np.pi,1*np.pi)

f_10=np.tan(x_10)
plt.plot(x_10,f_10,':oc',
         markersize=5, linewidth=2,
         markerfacecolor='c',
         markeredgecolor='c',
         markeredgewidth=1,
         label='$tan(x)$')

i_10=np.arctan(x_10)
plt.plot(x_10,i_10,'-^y',
         markersize=5, linewidth=1,
         markerfacecolor='y',
         markeredgecolor='y',
         markeredgewidth=1,
         label='$arctan(x)$')

plt.ylim(-10,10)

plt.xlabel('x')
plt.ylabel('y')
plt.title(" Comparison of TAN and ARCTAN ", fontsize=18)

plt.legend();

# %% [markdown]
# ### 11. Style Comparison
# - Choose one of your previous plots (Tasks 2-9)
# - Recreate it using three different styles: the default style, 'seaborn-whitegrid', and your chosen alternative style
# - Compare and contrast the appearances, discussing which style might be most appropriate for the specific data being plotted

# %%
# RUN THIS BEFORE ASSIGNING ANY STYLES
#default
x_8=np.linspace(0,4*np.pi)

f_8=x_8*np.sin(x_8)
plt.plot(x_8,f_8)

plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.title(" $f(x) = x sin(x)$ [Default Style] ")

plt.axis('tight')

plt.show()

# %%
#seaborn whitegrid
plt.style.use('seaborn-v0_8-whitegrid')
x_8=np.linspace(0,4*np.pi)

f_8=x_8*np.sin(x_8)
plt.plot(x_8,f_8)

plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.title(" $f(x) = x sin(x)$ [Seaborn Whitegrid] ")

plt.axis('tight')

plt.show()

# %%
#dark background
plt.style.use('dark_background')
x_8=np.linspace(0,4*np.pi)

f_8=x_8*np.sin(x_8)
plt.plot(x_8,f_8)

plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.title(" $f(x) = x sin(x)$ [Dark Background] ")

plt.axis('tight')

plt.show()

# %% [markdown]
# ### Analysis of Different Chart Styles
#
# I personally gravitate toward the `seaborn whitegrid` style because of the modern, minimalist look. In this case, I also think the the gridlines of the `seaborn whitegrid` style gives a better sense of the expanding oscillation of the function. However, the bright white gridlines of the `dark background` style are a bit harsh. In my opinion they're actually distracting from the plotted function because the gridlines are competing too much with the function for attention.
#
# I do notice that once I import a style, certain elements of that style remain even when I replace it with another. I assume this is because some style elements are defined in one but not in the other - essentially those undefined elements in the new style continue to use the defined elements of the replaced style. For example, the `dark background` seems to use a light cyan/teal line for the plotted function, which stays even when I switch back to `seaborn whitegrid`. Exercise #2 shows a blue line when using `seaborn whitegrid`, which is the same as the default. That suggests the `seaborn whitegrid` styling focuses on the plot background and grid rather than the plotted elements.
